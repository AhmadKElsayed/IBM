# %% [markdown]
# # 1. Import the Libraries

# %%
# %pip install pandas
# %pip install matplotlib
# %pip install numpy
# %pip install seaborn
# %pip install scikit-learn
# %pip install missingno
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in f:\programs\anaconda\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in f:\programs\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\programs\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in f:\programs\anaconda\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in f:\programs\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in f:\programs\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in f:\programs\anaconda\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in f:\programs\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in f:\programs\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\programs\anaconda\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in f:\programs\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in f:\programs\anaconda\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in f:\programs\anaconda\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in f:\programs\anaconda\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\programs\anaconda\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in f:\programs\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in f:\programs\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in f:\programs\anaconda\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in f:\programs\anaconda\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in f:\programs\anaconda\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in f:\programs\anaconda\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in f:\programs\anaconda\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in f:\programs\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in f:\programs\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\programs\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in f:\programs\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in f:\programs\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in f:\programs\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\programs\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in f:\programs\anaconda\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in f:\programs\anaconda\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in f:\programs\anaconda\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in f:\programs\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in f:\programs\anaconda\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in f:\programs\anaconda\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in f:\programs\anaconda\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in f:\programs\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in f:\programs\anaconda\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: missingno in c:\users\dell\appdata\roaming\python\python311\site-packages (0.5.2)
# Requirement already satisfied: numpy in f:\programs\anaconda\lib\site-packages (from missingno) (1.26.4)
# Requirement already satisfied: matplotlib in f:\programs\anaconda\lib\site-packages (from missingno) (3.8.0)
# Requirement already satisfied: scipy in f:\programs\anaconda\lib\site-packages (from missingno) (1.11.4)
# Requirement already satisfied: seaborn in f:\programs\anaconda\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in f:\programs\anaconda\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in f:\programs\anaconda\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in f:\programs\anaconda\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in f:\programs\anaconda\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in f:\programs\anaconda\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in f:\programs\anaconda\lib\site-packages (from matplotlib->missingno) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in f:\programs\anaconda\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in f:\programs\anaconda\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in f:\programs\anaconda\lib\site-packages (from seaborn->missingno) (2.1.4)
# Requirement already satisfied: pytz>=2020.1 in f:\programs\anaconda\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in f:\programs\anaconda\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in f:\programs\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
import missingno as msno
# %matplotlib inline

# %%
#Kfaya Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Import the dataset

# %%
filepath = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/medical_insurance_dataset.csv'
df = pd.read_csv(filepath, header = None, names =["age", "gender", "bmi", "no_of_children", "smoker", "region", "charges"])

# %%
df.head(10)
# Out:
#   age  gender     bmi  no_of_children smoker  region      charges
# 0  19       1  27.900               0      1       3  16884.92400
# 1  18       2  33.770               1      0       4   1725.55230
# 2  28       2  33.000               3      0       4   4449.46200
# 3  33       2  22.705               0      0       1  21984.47061
# 4  32       2  28.880               0      0       1   3866.85520
# 5  31       1  25.740               0      ?       4   3756.62160
# 6  46       1  33.440               1      0       4   8240.58960
# 7  37       1  27.740               3      0       1   7281.50560
# 8  37       2  29.830               2      0       2   6406.41070
# 9  60       1  25.840               0      0       1  28923.13692

# %%
df.replace('?', np.NaN, inplace = True)
df
# Out:
#      age  gender     bmi  no_of_children smoker  region      charges
# 0     19       1  27.900               0      1       3  16884.92400
# 1     18       2  33.770               1      0       4   1725.55230
# 2     28       2  33.000               3      0       4   4449.46200
# 3     33       2  22.705               0      0       1  21984.47061
# 4     32       2  28.880               0      0       1   3866.85520
# ...   ..     ...     ...             ...    ...     ...          ...
# 2767  47       1  45.320               1      0       4   8569.86180
# 2768  21       1  34.600               0      0       3   2020.17700
# 2769  19       2  26.030               1      1       1  16450.89470
# 2770  23       2  18.715               0      0       1  21595.38229
# 2771  54       2  31.600               0      0       3   9850.43200
#
# [2772 rows x 7 columns]

# %% [markdown]
# # 3. Data Wrangling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             2768 non-null   object
#  1   gender          2772 non-null   int64
#  2   bmi             2772 non-null   float64
#  3   no_of_children  2772 non-null   int64
#  4   smoker          2765 non-null   object
#  5   region          2772 non-null   int64
#  6   charges         2772 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 151.7+ KB

# %%
df.describe()
# Out:
#             gender          bmi  no_of_children       region       charges
# count  2772.000000  2772.000000     2772.000000  2772.000000   2772.000000
# mean      1.507215    30.701349        1.101732     2.559885  13261.369959
# std       0.500038     6.129449        1.214806     1.130761  12151.768945
# min       1.000000    15.960000        0.000000     1.000000   1121.873900
# 25%       1.000000    26.220000        0.000000     2.000000   4687.797000
# 50%       2.000000    30.447500        1.000000     3.000000   9333.014350
# 75%       2.000000    34.770000        2.000000     4.000000  16577.779500
# max       2.000000    53.130000        5.000000     4.000000  63770.428010

# %%
print(df.isna().sum())
msno.matrix(df)
# Out:
# age               4
# gender            0
# bmi               0
# no_of_children    0
# smoker            7
# region            0
# charges           0
# dtype: int64
# <Axes: >

# %%
#age imputing
df['age'] = df['age'].astype('float')
df['age'] = df['age'].fillna(df['age'].mean())

#smoker imputing
mostfreq = df['smoker'].value_counts().index[0]
df['smoker'] = df['smoker'].fillna(mostfreq)

df[["age","smoker"]] = df[["age","smoker"]].astype("int")

df.isna().sum()
# Out:
# age               0
# gender            0
# bmi               0
# no_of_children    0
# smoker            0
# region            0
# charges           0
# dtype: int64

# %%
df['charges'] = np.round(df['charges'],2)
df.head()
# Out:
#    age  gender     bmi  no_of_children  smoker  region   charges
# 0   19       1  27.900               0       1       3  16884.92
# 1   18       2  33.770               1       0       4   1725.55
# 2   28       2  33.000               3       0       4   4449.46
# 3   33       2  22.705               0       0       1  21984.47
# 4   32       2  28.880               0       0       1   3866.86

# %% [markdown]
# # 4. Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
#PLOT Function
def myplot(xx):
    fig = plt.figure(figsize = (8,6))
    sns.regplot(x=xx, y="charges", data=df, line_kws={"color": "red"})
    plt.title(f'charges vs {xx}')
    plt.ylim(0,)

# %%
myplot('bmi')

# %%
myplot('age')

# %%
plt.figure(figsize=(8,6))
ax = sns.boxplot(x = 'smoker', y = 'charges', data = df)
plt.xlabel('Smoking?')
plt.title('Smokers VS Non-Smokers')
ax.set_xticklabels(['Non-smoker', 'Smoker'])
# Out:
# [Text(0, 0, 'Non-smoker'), Text(1, 0, 'Smoker')]

# %% [markdown]
# # 5. Preparing Data

# %%
#Train Test Split
x_data = df.drop(['charges'], axis = 1)
y_data = df['charges']
x_train, x_test, y_train,y_test = train_test_split(x_data, y_data, test_size = 0.2, random_state = 14)
print(f'number of training samples: {x_train.shape[0]}')
print(f'number of test samples: {x_test.shape[0]}')
# Out:
# number of training samples: 2217
# number of test samples: 555

# %% [markdown]
# # 6. Model Development

# %%
#Plotting distribution function of Predictd and Actual Values
def mydisplot(hhhh, modelname):
    plt.figure(figsize=(8, 6))
        
    ax1 = sns.kdeplot(y_test, color="r", label='Actual Values')
    ax2 = sns.kdeplot(hhhh, color="b", label='Predicted Values', ax=ax1)
    
    plt.title(f'Actual Charges Vs Predicted Charges {modelname}')
    plt.xlabel('Medical Insurance Charges')
    
    plt.ylim(0,)
    plt.legend()

# %%
#Multiple Linear Regression
mlr = LinearRegression()
mlr.fit(x_train,y_train)
Yhat_mlr = mlr.predict(x_test)

print('model score on training data:', mlr.score(x_train, y_train))
print('mlr model score:', r2_score(y_test, Yhat_mlr))
# Out:
# model score on training data: 0.7433253373003431
# mlr model score: 0.7796613879641561

# %%
mydisplot(Yhat_mlr, 'MLR')

# %%
#Pipeline for Multiple Linear Regression with Standardization and PolyFeatures
Input_mlr = [('scaler',StandardScaler()), ('poly',PolynomialFeatures(include_bias = False)), ('LR_mod',LinearRegression())]
pipe_mlr = Pipeline(Input_mlr)
pipe_mlr.fit(x_train, y_train)
Yhat_pipe_mlr = pipe_mlr.predict(x_test)

print('Pipeline score:', r2_score(y_test, Yhat_pipe_mlr))
# Out:
# Pipeline score: 0.8644088507552943

# %%
mydisplot(Yhat_pipe_mlr, 'MLR Pipeline')

# %% [markdown]
# # 7. Model Refinement

# %%
#Ridge with GridSearchCV
rlr = Ridge()
parameters = [{'alpha':np.linspace(0, 1, 100)}]
Grid = GridSearchCV(rlr, parameters, cv = 5)
Grid.fit(x_train, y_train)

RLR = Grid.best_estimator_
Yhat_RLR = RLR.predict(x_test)
print('Ridge model score:',r2_score(y_test, Yhat_RLR))
# Out:
# Ridge model score: 0.7796769842950166

# %%
mydisplot(Yhat_RLR, 'Ridge Regression Model')

# %%
#Pipeline for Ridge with Standardization and PolyFeatures
Input_rlr = [('scaler',StandardScaler()), ('poly',PolynomialFeatures(include_bias = False)), ('RD_mod',Ridge(alpha = 0.2525252525))]
pipe_rlr = Pipeline(Input_rlr)
pipe_rlr.fit(x_train, y_train)
Yhat_pipe_rlr = pipe_rlr.predict(x_test)

print('Pipeline score:', r2_score(y_test, Yhat_pipe_rlr))
# Out:
# Pipeline score: 0.8644225174760862

# %%
mydisplot(Yhat_pipe_rlr, 'Ridge Regression Model Pipeline')

# %%
#Cross Validation Scores for MLR and Ridge
scores_mlr = cross_val_score(LinearRegression(), x_data, y_data, cv = 5)
print('Multiple Linear Regression Cross Validation:',scores_mlr)
scores_mlr = cross_val_score(Ridge(alpha = 0.25252525), x_data, y_data, cv = 5)
print('Ridge Regression Cross Validation:',scores_mlr)
# Out:
# Multiple Linear Regression Cross Validation: [0.73826314 0.75690927 0.76330761 0.74545018 0.74325342]
# Ridge Regression Cross Validation: [0.73829125 0.75690426 0.76329388 0.74543088 0.74326109]
